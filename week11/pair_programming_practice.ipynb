# %% [markdown]
# # Pair Programming

# %% [markdown]
# - 兩個人一起coding，分成以下兩個角色：
#     - Driver: 寫code的人，掌握details
#     - Navigator: 關注big picture和指出錯誤的人

# %% [markdown]
# ## Practice: 705. Design Hash Set

# %%
class ListNode:
    def __init__(self, val):
        self.val = val
        self.next = None

class MyHashSet:

    def __init__(self, capacity):
        """
        Initialize your data structure here.
        """
        self.capacity = capacity
        self.data = [None] * capacity
    
    def hash_function(self, key):
        return key % capacity
    
    def traversal(self, key):
        if self.data[self.hash_function(key)] != None:
            

    def add(self, key: int) -> None:
        put_in_set = self.hash_fiunction(key)
        if self.data[put_in_set] == None:
            self.data[put_in_set] = key
        else:
            

    def remove(self, key: int) -> None:
        

    def contains(self, key: int) -> bool:
        """
        Returns true if this set contains the specified element
        """
        
capacity = 5

# Your MyHashSet object will be instantiated and called as such:
# obj = MyHashSet()
# obj.add(key)
# obj.remove(key)
# param_3 = obj.contains(key)

# %%
#慈的想法
class ListNode:
    def __init__(self, val):
        self.val = val
        self.next = None
        """
        :type val: int
        :type next: ListNode
        :rtype: None        
        """
class LinkedList:
    def __init__(self, val = None):
        self.head = ListNode(val) 
        self.length = 0
        
class MyHashSet:
    def __init__(self, capacity):
        self.capacity = capacity # 幾個箱子
        self.data = [LinkedList()] * capacity # 每個箱子放入value
    
    def hash_function(self, key):
        return key % capacity
    
    def add(self, key):
        add_node = ListNode(key)
        list_ = self.data[self.hash_function(key)]
        if list_.head.val == None:
            list_.head = add_node
            list_.length += 1
        else:
            cur = list_.head
            for i in range(list_.length-1):
                cur = cur.next
            cur.next = add_node
            list_.length += 1
    
    def remove(self, key):
        list_ = self.data[self.hash_function(key)]
#         print(list_.head.val)
#         print(list_.head.next.val)
#         print(list_.head.next.next.val)
#         print(list_.head.next.next.next.val)
#         print(list_.head.next.next.next.next.val)
#         print(list_.head.next.next.next.next.next.val)
#         print(list_.length)
        
        if list_.head.val == None: #length == 0
            print('No node in the list.')
            return None
        
        cur = list_.head
        size = list_.length
        for i in range(list_.length-2):
#             print(cur.val)
            if cur.next:
                if cur.next.val == key:
#                     print(cur.next.val)
                    cur.next = cur.next.next
                    size -= 1
            cur = cur.next
#             print('round:', i,'---------')
        list_.length = size
        
        if list_.head.val == key:
            list_.head = list_.head.next
            list_.length -= 1
                               
    def contains(self, key):
        list_ = self.data[self.hash_function(key)]
        
        if list_.head.val == None: #length == 0
            print('No node in the list.')
            return False
        
        cur = list_.head
        for i in range(list_.length-1):
            
            print(cur.val)
            if cur.val == key:
                print('----')
                return True
            else:
                cur = cur.next
                print(cur.val)
            print('-')
        return False
            
        
        
capacity = 5
obj = MyHashSet(capacity)
# obj.add(1)
# obj.add(6)
# obj.add(1)
obj.add(12)
obj.add(7)
obj.add(12)
obj.add(17)
obj.add(22)
obj.add(12)
obj.remove(12)
obj.contains(17)

# obj.remove(key)
# param_3 = obj.contains(key)
# Out:
# 7
# 17
# -
# 17
# ----
# True

# %%
#慈的想法
class ListNode:
    def __init__(self, val):
        self.val = val
        self.next = None
        """
        :type val: int
        :type next: ListNode
        :rtype: None        
        """
class LinkedList:
    def __init__(self, val = None):
        self.head = ListNode(val) 
        self.length = 0
        
class MyHashSet:
    def __init__(self, capacity):
        self.capacity = capacity # 幾個箱子
        self.data = [LinkedList()] * capacity # 每個箱子放入value
    
    def hash_function(self, key):
        return key % capacity
    
    def add(self, key):
        add_node = ListNode(key)
        list_ = self.data[self.hash_function(key)]
        if list_.head.val == None:
            list_.head = add_node
            list_.length += 1
        else:
            cur = list_.head
            for i in range(list_.length-1):
                cur = cur.next
            cur.next = add_node
            list_.length += 1
    
    def remove(self, key):
        list_ = self.data[self.hash_function(key)]
        
        if list_.head.val == None: #length == 0
            print('No node in the list.')
            return None
        
        cur = list_.head
        size = list_.length
        for i in range(list_.length-2):
            if cur.next:
                if cur.next.val == key:
                    cur.next = cur.next.next
                    size -= 1
            cur = cur.next
        list_.length = size
        
        if list_.head.val == key:
            list_.head = list_.head.next
            list_.length -= 1
                               
    def contains(self, key):
        list_ = self.data[self.hash_function(key)]
        
        if list_.head.val == None: #length == 0
            print('No node in the list.')
            return False
        
        cur = list_.head
        for i in range(list_.length-1):
            
            print(cur.val)
            if cur.val == key:
                print('----')
                return True
            else:
                cur = cur.next
                print(cur.val)
            print('-')
        return False
            
        
        
capacity = 5
obj = MyHashSet(capacity)
# obj.add(1)
# obj.add(6)
# obj.add(1)
obj.add(12)
obj.add(7)
obj.add(12)
obj.add(17)
obj.add(22)
obj.add(12)
obj.remove(12)
obj.contains(17)

# obj.remove(key)
# param_3 = obj.contains(key)
