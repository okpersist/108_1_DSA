# %% [markdown]
# # Class Practice
# 2019.11.08 Fri

# %% [markdown]
# ## Ideas
# nums = [5, -5, 1, -10, 3]
# - `insert()`:把第一個插入的值設成head，其他依照大小放到二元分類樹規則下的地方
# - `compare()`:比大小，比節點小的放節點左下，比節點大的放節點右下，一層一層放到該節點最適合的位置

# %%
insert nums: 5, -5, 1, -10, 3

class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.head = None
    
    def insert(self, val):
        if self.Head == None:
            self.head = Node(val)
    
    def compare(self, val):
        if self.head != None:
            new_node = Node(val)
            cur_node = self.head
            if new_node.val <= self.head.val:
                if self.head.left == None:
                    self.head.left = new_node
                else:
                    cur_node = self.head.left
                    
            if new_node.val > self.head.val:
                self.head.right = new_node
# Out:
#   File "<ipython-input-3-a558b35bb55d>", line 1
#     insert nums: 5, -5, 1, -10, 3
#               ^
# SyntaxError: invalid syntax

# %%
# insert nums: 5, -5, 1, -10, 3

class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.head = None
    
    def insert(self, val):
        if self.head == None:
            self.head = Node(val)
        else:
            pass #稍後回來寫
            #new_node = Node(new_node)
            
    def compare(self, new_node, cur_node = self.head):
        if cur_node != None:
            if new_node.val <= cur_node.val:
                if cur_node.left == None:
                    cur_node.left = new_node
                else:
                    cur_node = cur_node.left
                    self.compare(new_node, cur_node)
            else:
                cur_node = self.head.left
                    
            if new_node.val > self.head.val:
                self.head.right = new_node

BST = BinarySearchTree()
BST.insert(5)
BST.insert(-5)
print(BST.head.val)
# Out:
# 5
