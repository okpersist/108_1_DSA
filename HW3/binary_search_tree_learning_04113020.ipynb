# %% [markdown]
# # Binary Search Tree 原理&流程圖&學習歷程
# 陳汶穗｜巨資四B｜04113020

# %% [markdown]
# # BST原理
# ## What is BST?
# - $BST$全名是$Binary$ $Search$ $Tree$是一種基於二元樹的樹狀結構，用以效率的尋找所需的資料，時間複雜度為$O(logn)$。
# - 一棵合理的BST滿足以下條件:
#     - 每個節點都要有顏色
#     - 根節點要是黑色
#     - 每個葉節點底下都預設有`null`節點，且`null`節點必須是黑色
#     - 每個分支的黑色節點數量要一致
#
#
# > 🖋**保持平衡並非二元搜尋樹的必要條件**:
# 無論新增或刪除值，不一定要讓樹一直保持在平衡的狀態(平衡的狀態代表子樹的最大長度差距不超過一，在原本最深層所有葉節點尚未被填滿之前不能把節點放到下層，此時要透過旋轉來滿足此條件)在紅黑樹中才要求樹要保持平衡。
#
#
# - BST可執行的function:
#     - Traversal | 走訪:
#         - 走訪是一種拜訪節點的系統化方式，不同的走訪方式可以幫助我們快速從節點找到我們要的資料（許多資料庫的原型就是建基於二元搜尋樹，把節點內儲存的東西換成各式資料而已）
#         - Depth First | 以深度優先的搜尋: 分成inorder/preorder/postorder三種
#         - Breathe First | 以廣度為優先的搜尋: 以某個節點為搜尋起點，從該起點同一深度的節點走訪完到下層，直到走訪到目標節點。
#
# ## Depth First Traversal
# - inorder: Top-down的走訪方式，由下而上從 `left` 開始走訪，依照 `left`->`root`->`right` 的方式走訪節點。左邊下面的子樹走訪完到`root`後再由上而下依照`left`->`root`->`right` 的方式走放右邊的子樹。
# - preorder: Top-down的走訪方式，從最上面的 `root` 開始走訪，依照 `root`->`left`->`right` 的方式走訪節點。一樣從左邊的子樹開始，先把所有的`left`走完，再所有左子樹都走完的情況下開始走右子樹。
# - postorder: bottom-up的走訪方式，從最後一個 `left` 開始走訪，依照 `left`->`right`->`root` 的方式走訪節點。每個子樹走訪完遇到`null`才回到上一層依照`left`->`right`->`root` 的方式繼續走訪節點

# %% [markdown]
# ## Flowchart
# ![](https://i.imgur.com/CmKsw0b.jpg)

# %% [markdown]
# ## 作業格式
# ```python
# class TreeNode(object):
#     def __init__(self,x):
#         self.val = x
#         self.left = None
#         self.right = None
#         """
#         :type val: int
#         :type left: TreeNode or None
#         :type right: TreeNode or None
#         """
# class Solution(object):
#     def insert(self, root, val):
#         """
#         :type root: TreeNode
#         :type val: int
#         :rtype: TreeNode(inserted node)
#         """
#     def delete(self, root, target):
#         """
#         :type root: TreeNode
#         :type target: int
#         :rtype: TreeNode(the root of new completed binary search tree) (cannot search())
#         """
#     def search(self, root, target):
#         """
#         :type root: TreeNode
#         :type target: int
#         :rtype: TreeNode(searched node)
#         """
#     def modify(self, root, target, new_val):
#         """
#         :type root: TreeNode
#         :type target: int
#         :type new_val: int
#         :rtype:TreeNode(the root of new completed binary search tree) (cannot search())
#         """
# ```

# %% [markdown]
# ## HW template

# %%
class TreeNode(object):
    def __init__(self,x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        
    def delete(self, root, target):

    def search(self, root, target):

    def modify(self, root, target, new_val):

# %% [markdown]
# ## 學習歷程

# %% [markdown]
# 👇先練習用`insert()`建構樹

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val) #錯誤點
                
        if new_node.val > root.val:
            if root.left == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val) #錯誤點
        
#     def delete(self, root, target):

#     def search(self, root, target):

#     def modify(self, root, target, new_val):
root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root ,3)
print(test1_output.val)

test2 = Solution()
test2_output = test2.insert(root ,3)
print(test2_output.val)
# Out:
# 5
# 3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-e5f8864b1129> in <module>
#      43 test2 = Solution()
#      44 test2_output = test2.insert(root ,3)
# ---> 45 print(test2_output.val)
#
# AttributeError: 'NoneType' object has no attribute 'val'

# %% [markdown]
# 👆 **AttributeError: 'NoneType' object has no attribute 'val'**
# 經過spyder debug mode發現因為`insert()`在判斷式缺乏返回的值導致`insert()`的東西沒有被存起來

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.left == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
        
#     def delete(self, root, target):

#     def search(self, root, target):

#     def modify(self, root, target, new_val):
root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root ,3)
print(test1_output.val)

test2 = Solution()
test2_output = test2.insert(root ,3)
print(test2_output.val)
# Out:
# 5
# 3
# 3

# %% [markdown]
# 🌞完成基本`insert()`，先確認insert值樹的排序是否正確，寫preorder走訪

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.left == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
                
#         ans = 'No number in this (sub) BST!'
#         print(ans)
#         self.preorder_traversal(root)
        
#     def delete(self, root, target):

#     def search(self, root, target):

#     def modify(self, root, target, new_val):
root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
print(test1_output.val)
test2_output = test1.insert(root, 3)
print(test2_output.val)
test3_output = test1.insert(root, -5)
print(test3_output.val)
test4_output = test1.insert(root, 8)
print(test4_output.val)
print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
# Out:
# 5
# 3
# 3
# -5
# 8
# ------------------------------
# preorder_traversal
# 5
# 3
# 3
# -5

# %% [markdown]
# 👆 **發現無法走訪所有節點**
# 看看debug mode
# ![](https://i.imgur.com/yWIAVbK.png)

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
        
#     def delete(self, root, target):

#     def search(self, root, target):

#     def modify(self, root, target, new_val):
root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
print(test1_output.val)
test2_output = test1.insert(root, 3)
print(test2_output.val)
test3_output = test1.insert(root, -5)
print(test3_output.val)
test4_output = test1.insert(root, 8)
print(test4_output.val)
print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
# Out:
# 5
# 3
# 3
# -5
# 8
# ------------------------------
# preorder_traversal
# 5
# 3
# 3
# -5
# 8

# %% [markdown]
# 👆 **發現原本`insert()`的以下區塊錯誤，現在可以順利走訪全部**
# ```python
#         if new_node.val > root.val:
#             if root.left == None: #這裡錯了，是root.right
#                 root.right = new_node
#                 return root.right
# ```

# %% [markdown]
# 👇**再多加幾個值測試**

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
#     def delete(self, root, target):               

#     def search(self, root, target):

#     def modify(self, root, target, new_val):

root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
# Out:
# 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10

# %% [markdown]
# 🌞完成`insert()`&`preorder_traversal()`，接著練習`delete()`

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
    
    #分成三種不同類型delete: is_no_child(無子節點), is_a_child(有一節點), is_two_children(有兩節點)
    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if node.left == None and node.right:
            print('left(X), right(O)')
            return True
        if node.left and node.right == None:
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        #如果root剛好等於target的話，分成三種情況來看怎麼刪除
        if root.val == target:
            
            #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None
                
            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            if self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)
            
            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            if self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                self.root_right_min_val(root).val = None
                self.delete(root, target)
                
#     def search(self, root, target):

#     def modify(self, root, target, new_val):

root = TreeNode(5)
print('root:', root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# root: 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10

# %% [markdown]
# 👆**此非正確結果，目前寫到當`root`==`target`時的情況**
# 繼續寫

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
    
    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        #如果root剛好等於target的話，分成三種情況來看怎麼刪除
        if root.val == target:
            
            #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None
                
            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            if self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)
            
            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            if self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                self.root_right_min_val(root).val = None
                self.delete(root, target)
        
        #如果root不是target，繼續往下找target
        if root.val != target:
            if root.left:
                if root.left.val == target:
                    self.delete(root.left, target)
            if root.right:
                if root.right.val == target:
                    self.delete(root.right, target)
        
#     def search(self, root, target):
#     def modify(self, root, target, new_val):

root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# left(O), right(X)
# left(O), right(X)
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10

# %% [markdown]
# 👆**`delete()`沒有語法錯誤，但traversal錯誤，沒有成功刪去值**
# 繼續修正

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
    
    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        #如果root剛好等於target的話，分成三種情況來看怎麼刪除
        if root.val == target:
            
            #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None
                
            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            if self.is_a_child(root) == True:
                if root.left:
                    root = root
                    self.delete(root, target)
                if root.right:
                    root = root
                    self.delete(root, target)
            
            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            if self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                self.root_right_min_val(root).val = None
                self.delete(root, target)
        
        #如果root不是target，繼續往下找target
        if root.val != target:
            while root.left:
                self.delete(root.left, target)
            if root.right:
                if root.right.val == target:
                    self.delete(root.right, target)
        
#     def search(self, root, target):
#     def modify(self, root, target, new_val):

root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# left(O), right(X)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-23-b261abc34712> in <module>
#     132 test1.preorder_traversal(root)
#     133 print('------------------------------')
# --> 134 test1.delete(root, target=3)
#     135 print('After deletion, new preorder traversal')
#     136 test1.preorder_traversal(root)
#
# <ipython-input-23-b261abc34712> in delete(self, root, target)
#     102         if root.val != target:
#     103             while root.left:
# --> 104                 self.delete(root.left, target)
#     105             if root.right:
#     106                 if root.right.val == target:
#
# <ipython-input-23-b261abc34712> in delete(self, root, target)
#      88                 if root.left:
#      89                     root = root
# ---> 90                     self.delete(root, target)
#      91                 if root.right:
#      92                     root = root
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-23-b261abc34712> in delete(self, root, target)
#      88                 if root.left:
#      89                     root = root
# ---> 90                     self.delete(root, target)
#      91                 if root.right:
#      92                     root = root
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# 👆**變成無限延長**
# 繼續修正

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
    
    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        #如果root剛好等於target的話，分成三種情況來看怎麼刪除
        if root.val == target:
            
            #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None
                
            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            if self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)
            return root
            
            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            if self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                self.root_right_min_val(root).val = None
                self.delete(root, target)
        
        #如果root不是target，繼續往下找target
        if root.val != target:
            root_node = root
            if root.left:
                left_node = self.delete(root_node.left, target)
            if root.right:
                right_node = self.delete(root_node.right, target)
        
#     def search(self, root, target):
#     def modify(self, root, target, new_val):

root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# left(O), right(X)
# left(O), right(X)
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                return new_node
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
                return new_node
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
    
    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
            return True #發現這裡原本少寫返回布林值
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        if root == None:
            return None
        if target > root.val:
            self.delete(root.right, target)
        if target < root.val:
            self.delete(root.left, target)
        else:
        
        #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None

            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            elif self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)

            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            elif self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                self.root_right_min_val(root).val = None
                self.delete(root, target)

        return root
        
#     def search(self, root, target):
#     def modify(self, root, target, new_val):

root = TreeNode(5)
print(root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# 5
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# left(O), right(X)
# left(O), right(X)
# no child
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10

# %% [markdown]
# 👆發現刪除的部分不能直接把複製的節點設成Node，會導致有子節點遺失；另外發現走到最下面後不會走到其他分支，檢查走訪邏輯是否有問題

# %% [markdown]
# 👇嘗試用list.append()重新建構一個修改數字後的BST，但輸出結果是錯誤的

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
result = []

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
    def preorder_traversal_2(self, root):
        if root.val:
            print(root.val)
            result.append(root.val)
        
        if root.left:
            self.preorder_traversal(root.left)
            
        if root.right:
            self.preorder_traversal(root.right)

    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
            return True #發現這裡原本少寫返回布林值
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        if root == None:
            return None
        
        if target > root.val:
            self.delete(root.right, target)
            
        if target < root.val:
            self.delete(root.left, target)
        else:
        
        #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None

            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            elif self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)

            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            elif self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                root.right = self.delete(root.right, target)
                
        return root
        
    def search(self, root, target):
        if root.val == target:
            print('search root:',root.val)
            return root
        
        if target < root.val:
            self.search(root.left, target)
        
        if target > root.val:
            print('target > root.val')
            print(root.right.val)
            self.search(root.right, target)
            
    def modify(self, root, target, new_val):
        if root:
            if root.val == target:
                root.val = new_val
        
        if root.left:
            self.modify(root.left, target, new_val)
        
        if root.right:
            self.modify(root.right, target, new_val)
            
        self.preorder_traversal_2(root)
        print(result)
        for node in result:
            self.insert(root, node)
            
        return root
                

root = TreeNode(5)
print('root:',root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
# print('------------------------------')
# print('preorder_traversal')
# test1.preorder_traversal(root)
# print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
print('------------------------------')
target = test1.search(root, 8)
print('search target:', target)
print('------------------------------')
modi = test1.modify(root, 7, 4)
print('the root after modify:', modi.val)
print('------------------------------')
print('After modifying, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# root: 5
# left(O), right(X)
# left(O), right(X)
# no child
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# target > root.val
# 8
# search root: 8
# search target: None
# ------------------------------
# -5
# [-5]
# 3
# -5
# -5
# [-5, 3]
# 3
# 3
# -5
# -5
# -5
# 3
# [-5, 3, 3]
# 6
# [-5, 3, 3, 6]
# 4
# 6
# -5
# 3
# 3
# 6
# [-5, 3, 3, 6, 4]
# 10
# [-5, 3, 3, 6, 4, 10]
# 8
# 4
# 6
# -5
# -5
# 3
# 3
# 3
# 3
# 6
# 4
# 6
# 10
# -5
# 3
# 3
# 6
# 4
# 10
# [-5, 3, 3, 6, 4, 10, 8]
# 5
# 3
# 3
# -5
# -5
# -5
# -5
# 3
# 3
# 3
# 8
# 4
# 6
# -5
# -5
# -5
# 3
# 3
# 3
# 3
# 3
# 3
# 6
# 4
# 4
# 6
# 6
# 8
# 10
# -5
# 3
# 3
# 6
# 4
# 10
# 10
# [-5, 3, 3, 6, 4, 10, 8, 5]
# the root after modify: 5
# ------------------------------
# After modifying, new preorder traversal
# 5
# 3
# 3
# -5
# -5
# -5
# -5
# -5
# 3
# 3
# 3
# 3
# 3
# 4
# 5
# 8
# 4
# 6
# -5
# -5
# -5
# 3
# 3
# 3
# 3
# 3
# 3
# 6
# 4
# 4
# 6
# 6
# 6
# 8
# 8
# 10
# -5
# 3
# 3
# 6
# 4
# 10
# 10
# 10

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
result = []

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
    def preorder_traversal_2(self, root):
        if root.val:
            print(root.val)
            result.append(root.val)
        
        if root.left:
            self.preorder_traversal(root.left)
            
        if root.right:
            self.preorder_traversal(root.right)

    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
            return True #發現這裡原本少寫返回布林值
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        if root == None:
            return None
        
        if target > root.val:
            self.delete(root.right, target)
            
        if target < root.val:
            self.delete(root.left, target)
        else:
        
        #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None

            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            elif self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)

            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            elif self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                root.right = self.delete(root.right, target)
                
        return root
        
    def search(self, root, target):
        if root.val == target:
            print('search root:', root.val)
            return root
        
        if target < root.val:
            self.search(root.left, target)
        
        if target > root.val:
            print('target > root.val')
            print(root.right.val)
            self.search(root.right, target)
            
    def modify(self, root, target, new_val):
        if root:
            if root.val == target:
                root.val = new_val
        
        if root.left:
            self.modify(root.left, target, new_val)
        
        if root.right:
            self.modify(root.right, target, new_val)
            
        return root
                

root = TreeNode(5)
print('root:',root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
print('------------------------------')
target = test1.search(root, 8)
print('search target:', target)
print('------------------------------')
modi = test1.modify(root, 7, 4)
print('the root after modify:', modi.val)
print('------------------------------')
print('After modifying, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# root: 5
# ------------------------------
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# left(O), right(X)
# left(O), right(X)
# no child
# After deletion, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# target > root.val
# 8
# search root: 8
# search target: None
# ------------------------------
# the root after modify: 5
# ------------------------------
# After modifying, new preorder traversal
# 5
# 3
# 3
# -5
# 8
# 4
# 6
# 10

# %% [markdown]
# 👆暫時總結幾個遇到的問題:
# 1. search() 中 明明我單獨印出是有找到search的target值，可是為什麼直接ｐｒｉｎｔ的時候卻是返回Ｎｏｎｅ呢
# 2. 為什麼我運行 modify() 後跑出來的結果第一個root變成-5呢(上上個測試結果)
# 3. 為什麼delete() 無法刪除想刪除的值呢? 刪除後走訪結果還是一樣
# 要繼續修正，希望截止前來得及找到問題

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
result = []

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
    def preorder_traversal_2(self, root):
        if root.val:
            print(root.val)
            result.append(root.val)
        
        if root.left:
            self.preorder_traversal(root.left)
            
        if root.right:
            self.preorder_traversal(root.right)

    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
            return True #發現這裡原本少寫返回布林值
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        if root == None:
            return None
        
        if target > root.val:
            self.delete(root.right, target)
            
        if target < root.val:
            self.delete(root.left, target)
        else:
        
        #如果整個tree就只有root一個元素的話，直接把該元素改成None
            if self.is_no_child(root) == True:
                root = None

            #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
            elif self.is_a_child(root) == True:
                if root.left:
                    root = root.left
                    self.delete(root, target)
                if root.right:
                    root = root.right
                    self.delete(root, target)

            #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
            elif self.is_two_children(root) == True:
                root.val = self.root_right_min_val(root).val
                root.right = self.delete(root.right, target)
                
        return root
        
    def search(self, root, target):
        if root.val == target:
            print('search root:', root.val)
            return root
        
        if target < root.val:
            self.search(root.left, target)
        
        if target > root.val:
            print('target > root.val')
            print(root.right.val)
            self.search(root.right, target)
            
    def modify(self, root, target, new_val):
        if root:
            if root.val == target:
                root.val = new_val
        
        if root.left:
            self.modify(root.left, target, new_val)
        
        if root.right:
            self.modify(root.right, target, new_val)
            
        return root
 
# Reference: Data Structures and Algorithms Bootcamp:Binary Trees / by Jonathan Rasmusson | Former Spotify Engineer | https://www.udemy.com/course/data-structures-and-algorithms-bootcamp/learn/lecture/9520088?start=195#content

# %%
#練習用測資 5, 3, 3, -5, 8, 7, 10, 6
result = []

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    
    def insert(self, root, val):
        if root == None:
            new_node = TreeNode(val)
            root = new_node
            return root
        
        new_node = TreeNode(val)
        
        if new_node.val <= root.val:
            if root.left == None:
                root.left = new_node
                return root.left
            else:
                self.insert(root.left, new_node.val)
                
        if new_node.val > root.val:
            if root.right == None:
                root.right = new_node
                return root.right
            else:
                self.insert(root.right, new_node.val)
            
    def preorder_traversal(self, root):
        if root.val:
            print(root.val)
        
        if root.left:
            left = self.preorder_traversal(root.left)
            
        if root.right:
            right = self.preorder_traversal(root.right)
            
    def preorder_traversal_2(self, root):
        if root.val:
            print(root.val)
            result.append(root.val)
        
        if root.left:
            self.preorder_traversal(root.left)
            
        if root.right:
            self.preorder_traversal(root.right)

    def is_no_child(self, node):
        if node.left == None and node.right == None:
            print('no child')
            return True
        else:
            return False
        
    def is_a_child(self, node):
        if (node.left == None) and node.right:
            print('left(X), right(O)')
            return True
        if node.left and (node.right == None):
            print('left(O), right(X)')
            return True
        else:
            return False
    
    def is_two_children(self, node):
        if node.left and node.right:
            print('left(O), right(O)')
            return True #發現這裡原本少寫返回布林值
        else:
            return False
    
    def root_right_min_val(self, root):
        if root:
            count = 1
            cur_root = root
            if cur_root.right and count <=1:
                cur_root = root.right
                count+=1
                self.root_right_min_val(cur_root.left)
            while cur_root.left:
                cur_root = root.left
        return cur_root
            
    def delete(self, root, target):
        if root == None:
            return None
        
        if target > root.val:
            self.search(root.right, target)
            
        elif target < root.val:
            self.search(root.left, target)
        
        
        #如果整個tree就只有root一個元素的話，直接把該元素改成None
        if self.is_no_child(root) == True:
            root = None

        #如果root有某一邊有子節點，用該節點取代原本的root，這樣原本的root就消失了，然後繼續往下檢查看有沒有符合target的元素
        elif self.is_a_child(root) == True:
            if root.left:
                root = root.left
                self.delete(root, target)
            if root.right:
                root = root.right
                self.delete(root, target)

        #如果root兩邊都有子節點，先找到在root右子樹中最小的值，用該值取代root，刪除該值原本的節點後，再檢查新的節點是不是target
        elif self.is_two_children(root) == True:
            root.val = self.root_right_min_val(root).val
            root.right = self.delete(self.root_right_min_val(root), target)
                
        return root
        
    def search(self, root, target):
        if root.val == target:
            print('search root:', root.val)
            return root
        
        if target < root.val:
            self.search(root.left, target)
        
        if target > root.val:
            print('target > root.val')
            print(root.right.val)
            self.search(root.right, target)
            
    def modify(self, root, target, new_val):
        if root:
            if root.val == target:
                root.val = new_val
        
        if root.left:
            self.modify(root.left, target, new_val)
        
        if root.right:
            self.modify(root.right, target, new_val)
            
        return root
                

root = TreeNode(5)
print('root:',root.val)

test1 = Solution()
test1_output = test1.insert(root, 3)
# print(test1_output.val)
test2_output = test1.insert(root, 3)
# print(test2_output.val)
test3_output = test1.insert(root, -5)
# print(test3_output.val)
test4_output = test1.insert(root, 8)
# print(test4_output.val)
test5_output = test1.insert(root, 7)
# print(test5_output.val)
test6_output = test1.insert(root, 10)
# print(test6_output.val)
test7_output = test1.insert(root, 6)
# print(test7_output.val)
print('------------------------------')
print('preorder_traversal')
test1.preorder_traversal(root)
print('------------------------------')
test1.delete(root, target=3)
print('After deletion, new preorder traversal')
test1.preorder_traversal(root)
print('------------------------------')
target = test1.search(root, 8)
print('search target:', target)
print('------------------------------')
modi = test1.modify(root, 7, 4)
print('the root after modify:', modi.val)
print('------------------------------')
print('After modifying, new preorder traversal')
test1.preorder_traversal(root)
# Out:
# root: 5
# ------------------------------
# preorder_traversal
# 5
# 3
# 3
# -5
# 8
# 7
# 6
# 10
# ------------------------------
# search root: 3
# left(O), right(O)

# %% [markdown]
# ## Reference
# [Data Structures and Algorithms Bootcamp:Binary Trees / by Jonathan Rasmusson / Former Spotify Engineer](https://www.udemy.com/course/data-structures-and-algorithms-bootcamp/learn/lecture/9520088?start=195#content)
