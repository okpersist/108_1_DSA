# %% [markdown]
# # HW2: Heap Sort 學習歷程與Reference
# 陳汶穗｜巨資4B｜04113020
#
# --------
# 1. [對Heapsort的理解](https://github.com/okpersist/108_1_DSA#heap-sort)
# > 怕整份作業說明太長所以另外放在github readme網址
# 2. 流程圖:
# ![](https://i.imgur.com/dWiQ292.png)
#
# ![](https://i.imgur.com/amYIzzi.png)
# ![](https://i.imgur.com/qYCMolF.png)
# 3. 兩者的比較放在<font color=#41D3BD>**Mergesort的學習歷程**</font>中

# %% [markdown]
# ## 初始想法: 做一個產生max heap的算法
# - `find_index_value` & `find_value`:算出每個位置對應的主節點及左右節點，以及節點的值
# - 對節點由下而上或由上而下的比大小，更換排序位置
#     - `swap()`: 交換位置
#     - `heapify()`: 比大小
# - `heap_sort()`: main function
#
# ---
# 發現兩個問題:
# 1. 不知道怎麼調用方法
# 2. 不確定倒序for loop怎麼寫

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_value(self, nums, i):
        self.val = nums[i]
        self.left = nums[2*i+1]
        self.right = nums[2*i+2]
        self.parent = nums[(i-1)//2]
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):
        if n.left:
            if n.val < n.left:
                swap(n.val, n.left)
                
        if n.right:
            if n.val < n.right:
                swap(n.val, n.right)
        
        n = n.parent() #不知道怎麼調用方法
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums

        for n in range(len(nums),-1,-1):#不確定倒序for loop怎麼寫
            heapify()

# %% [markdown]
# ## 1. 不知道怎麼調用方法: 測試自己對迴圈倒序的理解

# %%
nums = [1, 4, 2, 3.6]
for n in range(len(nums),-1,-1):
    print(n)
# Out:
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ## 2. 不確定倒序for loop怎麼寫: 測試自己對調用方法的理解
# > 🕵️‍♀️思考與查資料:怎麼樣才能使別的方法中的物件有其他方法物件的屬性呢
#
# - AttributeError: 'function' object has no attribute 'parent'
#     - 調用失敗出現的錯誤

# %%
nums = [1, 4, 2, 3.6]
class test:
    def find_value(self, nums, i):
        self.val = nums[i]
        self.left = nums[2*i+1]
        self.right = nums[2*i+2]
        self.parent = nums[(i-1)//2]

    def call(self, nums, n):
        self.find_value.parent(nums, n)#錯誤點
        
    
t = test()
t.call(nums,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d6a45b5e967f> in <module>
#      13
#      14 t = test()
# ---> 15 t.call(nums,1)
#
# <ipython-input-13-d6a45b5e967f> in call(self, nums, n)
#       9     #怎麼樣才能使別的方法中的物件有其他方法物件的屬性呢
#      10     def call(self, nums, n):
# ---> 11         self.find_value.parent(nums, n)
#      12
#      13
#
# AttributeError: 'function' object has no attribute 'parent'

# %% [markdown]
# - SyntaxError: invalid syntax
#     - 調用失敗出現的錯誤

# %%
nums = [1, 4, 2, 3.6]
class test:
    
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            return self.val = nums[i]
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            return self.left = nums[2*i+1]
        else:
            print(i+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            return self.right = nums[2*i+2]
        else:
            print(i+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            return self.parent = nums[(i-1)//2]
        else:
            print(i+' has no parent node.')

    def call_(self, nums, n):
        n_parent = self.parents(nums, n)
        print(n_parent)
        
t = test(nums,1)
t.calll(nums,1)
# Out:
#   File "<ipython-input-33-af05ddd5f82d>", line 6
#     return self.val = nums[i]
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 成功測試如何調用方法屬性
# 把所有function分開寫並return值

# %%
nums = [1, 4, 2, 3.6]
class test:
    
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print(i+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print(i+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(i+' has no parent node.')

    def call_(self, nums, n):
        n_parent = self.find_parent(nums, n)#這時才可成功調用
        return n_parent
        
t = test()
t.call_(nums,1)
# Out:
# 1

# %% [markdown]
# ## 修改初始想法，並繼續寫heap sort 的部分

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print(i+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print(i+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(i+' has no parent node.')
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):#修改的地方
        if self.find_left(nums, n) and self.find_val(nums, n):
            if val < left:
                swap(val, left)
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if val < right:
                swap(val, right)
        
        n = self.find_parent(nums, n)
        heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums),-1,-1):
            heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            swap(maxi, num[end_of_nums])
            heapify(nums, end_of_nums-1)
            end_of_nums -= 1
            return nums

test = Solution()
test.heap_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-cd0bf874315c> in <module>
#      71
#      72 test = Solution()
# ---> 73 test.heap_sort(nums)
#
# <ipython-input-35-cd0bf874315c> in heap_sort(self, nums)
#      60
#      61         for n in range(len(nums),-1,-1):
# ---> 62             heapify(nums, n)
#      63
#      64         for num in range(len(nums),-1,-1):
#
# NameError: name 'heapify' is not defined

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print(str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print(str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):#修改的地方
        if self.find_left(nums, n) and self.find_val(nums, n):
            if val < left:
                swap(val, left)
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if val < right:
                swap(val, right)
        
        n = self.find_parent(nums, n)
        heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums),-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            self.swap(maxi, num[end_of_nums])
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-a622d2624fe1> in <module>
#      71
#      72 test = Solution()
# ---> 73 test.heap_sort(nums)
#
# <ipython-input-36-a622d2624fe1> in heap_sort(self, nums)
#      60
#      61         for n in range(len(nums),-1,-1):
# ---> 62             self.heapify(nums, n)
#      63
#      64         for num in range(len(nums),-1,-1):
#
# <ipython-input-36-a622d2624fe1> in heapify(self, nums, n)
#      44
#      45     def heapify(self, nums, n):#修改的地方
# ---> 46         if self.find_left(nums, n) and self.find_val(nums, n):
#      47             if val < left:
#      48                 swap(val, left)
#
# <ipython-input-36-a622d2624fe1> in find_left(self, nums, i)
#      22             return left
#      23         else:
# ---> 24             print(i+' has no left node.')
#      25
# ...

# %% [markdown]
# ## 出現重複印出的情況
# 使用debug mode發現回傳index的邏輯錯誤
# ![](https://i.imgur.com/vOaDEgS.png)

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print(str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print(str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):#修改的地方
        if self.find_left(nums, n) and self.find_val(nums, n):
            if val < left:
                swap(val, left)
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if val < right:
                swap(val, right)
        
        n = self.find_parent(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums),-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            self.swap(maxi, num[end_of_nums])
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# 4 has no left node.
# 4 has no right node.
# ...

# %% [markdown]
# ## Errors
# 接下來犯了一些語法錯誤
# - NameError: name 'val' is not defined: 呼叫其他function回傳值語法的錯誤
# - NameError: name 'swap' is not defined: 同上

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i>0:
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):#修改的地方
        if self.find_left(nums, n) and self.find_val(nums, n):
            if val < left:
                swap(val, left)
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if val < right:
                swap(val, right)
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            self.swap(maxi, num[end_of_nums])
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 3 has no left node.
# index 3 has no right node.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8a5c36a75779> in <module>
#      80
#      81 test = Solution()
# ---> 82 test.heap_sort(nums)
#
# <ipython-input-39-8a5c36a75779> in heap_sort(self, nums)
#      69
#      70         for n in range(len(nums)-1,-1,-1):
# ---> 71             self.heapify(nums, n)
#      72
#      73         for num in range(len(nums),-1,-1):
#
# <ipython-input-39-8a5c36a75779> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
#      66     def heap_sort(self, nums):
#
# <ipython-input-39-8a5c36a75779> in heapify(self, nums, n)
#      54     def heapify(self, nums, n):#修改的地方
#      55         if self.find_left(nums, n) and self.find_val(nums, n):
# ---> 56             if val < left:
# ...

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i>0:
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):#修改的地方
        if self.find_left(nums, n) and self.find_val(nums, n):
            if self.find_val(nums, n) < self.find_left(nums, n):
                swap(self.find_val(nums, n), self.find_left(nums, n))
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if self.find_val(nums, n) < self.find_right(nums, n):
                swap(self.find_val(nums, n), self.find_right(nums, n))
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            self.swap(maxi, num[end_of_nums])
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 3 has no left node.
# index 3 has no right node.
# index 1 has no right node.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-bf0926775248> in <module>
#      80
#      81 test = Solution()
# ---> 82 test.heap_sort(nums)
#
# <ipython-input-41-bf0926775248> in heap_sort(self, nums)
#      69
#      70         for n in range(len(nums)-1,-1,-1):
# ---> 71             self.heapify(nums, n)
#      72
#      73         for num in range(len(nums),-1,-1):
#
# <ipython-input-41-bf0926775248> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
#      66     def heap_sort(self, nums):
#
# <ipython-input-41-bf0926775248> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
# ...

# %% [markdown]
# ## Errors
# 因為邏輯有問題導致的一些Error
# - TypeError: unsupported operand type(s) for *: 'int' and 'NoneType': 邏輯撰寫有誤，導致python回傳的NoneType跟數字進行比較
# - IndexError: list index out of range: 遞迴次數跟設想的有出入

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i>0:
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
        
    def swap(self, a, b):
        a, b = b, a
        
    def heapify(self, nums, n):
        if self.find_left(nums, n) and self.find_val(nums, n):
            if self.find_val(nums, n) < self.find_left(nums, n):
                self.swap(self.find_val(nums, n), self.find_left(nums, n))
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if self.find_val(nums, n) < self.find_right(nums, n):
                self.swap(self.find_val(nums, n), self.find_right(nums, n))
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = nums[0]
            end_of_nums = len(nums)-1
            self.swap(maxi, num[end_of_nums])
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 3 has no left node.
# index 3 has no right node.
# index 1 has no right node.
# index 0 has no parent index.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-46e43c32529f> in <module>
#      80
#      81 test = Solution()
# ---> 82 test.heap_sort(nums)
#
# <ipython-input-42-46e43c32529f> in heap_sort(self, nums)
#      69
#      70         for n in range(len(nums)-1,-1,-1):
# ---> 71             self.heapify(nums, n)
#      72
#      73         for num in range(len(nums),-1,-1):
#
# <ipython-input-42-46e43c32529f> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
#      66     def heap_sort(self, nums):
#
# <ipython-input-42-46e43c32529f> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ...

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
    
    def find_index_value(self, i):
        self.idx_left = 2*i+1
        self.idx_right = 2*i+2
        self.idx_parent = (i-1)//2
        
    def find_val(self, nums, i):
        if i <= len(nums)-1 and i!= None:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1 and i!= None:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2 and i!= None:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
            
    def find_parent(self, nums, i):
        if i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i>0:
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
        
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
        
    def heapify(self, nums, n):
        if self.find_left(nums, n) and self.find_val(nums, n):
            if self.find_val(nums, n) < self.find_left(nums, n):
                self.swap(nums, self.find_val(nums, n), self.find_left(nums, n))
                
        if self.find_right(nums, n) and self.find_val(nums,n):
            if self.find_val(nums, n) < self.find_right(nums, n):
                self.swap(nums, self.find_val(nums, n), self.find_right(nums, n))
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = 0
            end_of_nums = len(nums)-1
            self.swap(nums, maxi, end_of_nums)
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 3 has no left node.
# index 3 has no right node.
# index 1 has no right node.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-4f2ae3502a4b> in <module>
#      80
#      81 test = Solution()
# ---> 82 test.heap_sort(nums)
#
# <ipython-input-44-4f2ae3502a4b> in heap_sort(self, nums)
#      69
#      70         for n in range(len(nums)-1,-1,-1):
# ---> 71             self.heapify(nums, n)
#      72
#      73         for num in range(len(nums),-1,-1):
#
# <ipython-input-44-4f2ae3502a4b> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
#      66     def heap_sort(self, nums):
#
# <ipython-input-44-4f2ae3502a4b> in heapify(self, nums, n)
#      62
#      63         n = self.find_parent_index(nums, n)
# ---> 64         self.heapify(nums, n)
#      65
# ...

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
        
    def find_val(self, nums, i):
        if i <= len(nums)-1 and i!= None:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
        
    def find_val_index(self, nums, i):
        if i <= len(nums)-1 and i!= None:
            self.val_index = i
            val_index = self.val_index
            return val_index
        else:
            return nums
    
    def find_left(self, nums, i):
        if len(nums) > 2*i+1 and i!= None:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
            
    def find_left_index(self, nums, i):
        if len(nums) > 2*i+1 and i!= None:
            self.left_index = 2*i+1
            left_index = self.left_index
            return left_index
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if len(nums) > 2*i+2 and i!= None:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
    
    def find_right_index(self, nums, i):
        if len(nums) > 2*i+2 and i!= None:
            self.right_index = 2*i+2
            right_index = self.right_index
            return right_index
        else:
            print('index '+str(i)+' has no right node.')    
            
    def find_parent(self, nums, i):
        if i>0 and i!= None:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i>0 and i!= None:
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
        
    def heapify(self, nums, n):#修改的地方
        if len(nums) > 2*n+1 and n <= len(nums)-1:
            val = self.find_val(nums, n)
            val_index = self.find_val_index(nums, n)
            left = self.find_left(nums, n)
            left_index = self.find_left_index(nums, n)
            if val < left:
                self.swap(nums, val_index, left_index)
                
        if len(nums) > 2*n+2 and n <= len(nums)-1:
            if self.find_val(nums, n) < self.find_right(nums, n):
                val = self.find_val(nums, n)
                val_index = self.find_val_index(nums, n)
                right = self.find_right(nums, n)
                right_index = self.find_right_index(nums, n)
                self.swap(nums, val_index, right_index)
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = 0
            end_of_nums = len(nums)-1
            self.swap(nums, maxi, end_of_nums)
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 0 has no parent index.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-e1a5fc0accf8> in <module>
#     106
#     107 test = Solution()
# --> 108 test.heap_sort(nums)
#
# <ipython-input-49-e1a5fc0accf8> in heap_sort(self, nums)
#      95
#      96         for n in range(len(nums)-1,-1,-1):
# ---> 97             self.heapify(nums, n)
#      98
#      99         for num in range(len(nums),-1,-1):
#
# <ipython-input-49-e1a5fc0accf8> in heapify(self, nums, n)
#      88
#      89         n = self.find_parent_index(nums, n)
# ---> 90         self.heapify(nums, n)
#      91
#      92     def heap_sort(self, nums):
#
# <ipython-input-49-e1a5fc0accf8> in heapify(self, nums, n)
#      88
#      89         n = self.find_parent_index(nums, n)
# ---> 90         self.heapify(nums, n)
#      91
#      92     def heap_sort(self, nums):
#
# ...

# %% [markdown]
# ## 陷入無窮迴圈
# 用debug mode發現`heapify()`的停止條件設定有誤，無法成功讓程式如想像般停止。

# %%
nums = [1, 4, 2, 3.6]

class Solution(object):
        
    def find_val(self, nums, i):
        if i!= None and i <= len(nums)-1:
            self.val = nums[i]
            val = self.val
            return val
        else:
            return nums
        
    def find_val_index(self, nums, i):
        if i!= None and i <= len(nums)-1:
            self.val_index = i
            val_index = self.val_index
            return val_index
        else:
            return nums
    
    def find_left(self, nums, i):
        if i!= None and len(nums) > 2*i+1:
            self.left = nums[2*i+1]
            left = self.left
            return left
        else:
            print('index '+str(i)+' has no left node.')
            
    def find_left_index(self, nums, i):
        if i!= None and len(nums) > 2*i+1:
            self.left_index = 2*i+1
            left_index = self.left_index
            return left_index
        else:
            print('index '+str(i)+' has no left node.')
        
    def find_right(self, nums, i):
        if i!= None and len(nums) > 2*i+2:
            self.right = nums[2*i+2]
            right = self.right
            return right
        else:
            print('index '+str(i)+' has no right node.')
    
    def find_right_index(self, nums, i):
        if i!= None and len(nums) > 2*i+2:
            self.right_index = 2*i+2
            right_index = self.right_index
            return right_index
        else:
            print('index '+str(i)+' has no right node.')    
            
    def find_parent(self, nums, i):
        if i!= None and i>0:
            self.parent = nums[(i-1)//2]
            parent = self.parent
            return parent
        else:
            print(str(i)+' has no parent node.')
            
    def find_parent_index(self, nums, i):
        if i!= None and i>0 :
            self.parent_index = (i-1)//2
            parent_index = self.parent_index
            return parent_index
        else:
            print('index '+str(i)+' has no parent index.')
                    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
        
    def heapify(self, nums, n):#修改的地方
        if n!= None and len(nums) > 2*n+1 and n <= len(nums)-1:
            val = self.find_val(nums, n)
            val_index = self.find_val_index(nums, n)
            left = self.find_left(nums, n)
            left_index = self.find_left_index(nums, n)
            if val < left:
                self.swap(nums, val_index, left_index)
                
        if n!= None and len(nums) > 2*n+2 and n <= len(nums)-1:
            if self.find_val(nums, n) < self.find_right(nums, n):
                val = self.find_val(nums, n)
                val_index = self.find_val_index(nums, n)
                right = self.find_right(nums, n)
                right_index = self.find_right_index(nums, n)
                self.swap(nums, val_index, right_index)
        
        n = self.find_parent_index(nums, n)
        self.heapify(nums, n)
        
    def heap_sort(self, nums):
        if len(nums)<2:
            return nums
        
        for n in range(len(nums)-1,-1,-1):
            self.heapify(nums, n)
        
        for num in range(len(nums),-1,-1):
            maxi = 0
            end_of_nums = len(nums)-1
            self.swap(nums, maxi, end_of_nums)
            self.heapify(nums, end_of_nums-1)
            end_of_nums -= 1
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# index 0 has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# index None has no parent index.
# ...

# %% [markdown]
# ## 參考別人的程式後，嘗試用其他更直覺的方式撰寫，發現排序結果錯誤
# ![](https://i.imgur.com/dpcNhIO.png)
# debug mode可以看出問題出在`heap_sort()`第二次迴圈開始交換的地方，因為heapify不會自動除去nums已經排序好的元素，因此交換後會打亂原本排序好的順序。

# %%
nums = [1, 4, 2, 3.6]
size = len(nums)
class Solution(object):
    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
    
    def heapify(self, nums, index):
        left = 2*index + 1
        right = 2*index +2
        
        if size<2:
            return nums
        
        if left <= size-1 and nums[left] > nums[index]:
            self.swap(nums, index, left)
            self.heapify(nums, left)
        if right <= size-1 and nums[right] > nums[index]:
            self.swap(nums, index, right)
            self.heapify(nums, right)
        
    def heap_sort(self,nums):
        for element in range(size-1, -1, -1):
            self.heapify(nums, element)
        
        for n in range(size-1):
            cur_end_point = size-1
            self.swap(nums, 0, cur_end_point)
            self.heapify(nums, 0)
            cur_end_point -= 1
            print(nums)
            return nums

test = Solution()
test.heap_sort(nums)
# Out:
# [3.6, 4, 2, 1]
# [3.6, 4, 2, 1]

# %% [markdown]
# ## IndexError: list index out of range
# 想法: 利用result把結果另外存起來避免打亂排序，但發生語法錯誤。
#
# ※此方法會占用額外空間，最好還是可以使用原本的list重新排列。

# %%
nums = [1, 4, 2, 3.6]
result = []
size = len(nums)
class Solution(object):
    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
    
    def heapify(self, nums, index):
        left = 2*index + 1
        right = 2*index +2
        
        if size<2:
            return nums
        
        if left <= size-1 and nums[left] > nums[index]:
            self.swap(nums, index, left)
            self.heapify(nums, left)
        if right <= size-1 and nums[right] > nums[index]:
            self.swap(nums, index, right)
            self.heapify(nums, right)
        
    def heap_sort(self,nums):
        for element in range(size-1, -1, -1):
            self.heapify(nums, element)
        
        for n in range(size-1):
            cur_end_point = size-1
            self.swap(nums, 0, cur_end_point)
            result[0].append(nums.pop(size-1)) #錯誤點
            self.heapify(nums, 0)
            cur_end_point -= 1
            print(nums)
            return nums

test = Solution()
test.heap_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-043a09a23a6a> in <module>
#      35
#      36 test = Solution()
# ---> 37 test.heap_sort(nums)
#
# <ipython-input-14-043a09a23a6a> in heap_sort(self, nums)
#      28             cur_end_point = size-1
#      29             self.swap(nums, 0, cur_end_point)
# ---> 30             result[0].append(nums.pop(size-1))
#      31             self.heapify(nums, 0)
#      32             cur_end_point -= 1
#
# IndexError: list index out of range

# %% [markdown]
# ## 嘗試寫加上條件限制版本的heapify，但沒能正確排序

# %%
nums = [1, 4, 2, 3.6]
size = len(nums)

class Solution(object):
    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
    
    def heapify(self, nums, index):
        left = 2*index + 1
        right = 2*index +2
        
        if size<2:
            return nums
        
        if left <= size-1 and nums[left] > nums[index]:
            self.swap(nums, index, left)
            self.heapify(nums, left)
        if right <= size-1 and nums[right] > nums[index]:
            self.swap(nums, index, right)
            self.heapify(nums, right)
    
    #[4,3.6,2,1] -> [1,3.6,2,4]
    def heapify_limit(self, nums, start=0):
        l = 2*start+1
        r = 2*start+2
        cur_len = len(nums)-1
        
        self.swap(nums, 0, cur_len)
        cur_len -= 1
        
        if cur_len<2:
            return nums
        
        if l <= cur_len and nums[l] > nums[start]:
            self.swap(nums, start, l)
            self.heapify_limit(nums, l)
                
        if r <= cur_len and nums[r] > nums[start]:
            self.swap(nums, start, r)
            self.heapify_limit(nums, r)
        
    def heap_sort(self,nums):
        for element in range(size-1, -1, -1):
            self.heapify(nums, element)
        
        self.heapify_limit(nums, 0)
        return nums

test = Solution()
test.heap_sort(nums)
# Out:
# [4, 1, 2, 3.6]

# %% [markdown]
# ## 修正`heapify_down()`邏輯後成功跑出

# %%
nums = [4,3.6,2,1]
result = []
size = len(nums)

class Solution(object):
    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
    
    def heapify(self, nums, index):
        left = 2*index + 1
        right = 2*index +2
        size = len(nums)
        
        if size<2:
            return nums
        
        if left <= size-1 and nums[left] > nums[index]:
            self.swap(nums, index, left)
            self.heapify(nums, left)
        if right <= size-1 and nums[right] > nums[index]:
            self.swap(nums, index, right)
            self.heapify(nums, right)
    
    #[4,3.6,2,1] -> [1,3.6,2,4]
    def heapify_down(self, nums):
        for rounds in range(size-1, -1, -1):
            self.swap(nums, 0, rounds)
            result.append(nums.pop())
            self.heapify(nums, 0)
        return result
        
    def heap_sort(self,nums):
        for element in range(size-1, -1, -1):
            self.heapify(nums, element)
        
        ans = self.heapify_down(nums)
        ans = ans[::-1] #用append是由大到小排列，所以反過來
        return ans

test = Solution()
test.heap_sort(nums)
# Out:
# [1, 2, 3.6, 4]

# %% [markdown]
# ## 嘗試其他list

# %%
nums = [1, 4, 2, 3.6, -1, 0, 25, -34, 8, 9, 1, 0]
result = []
size = len(nums)

class Solution(object):
    
    def swap(self, nums, a, b):
        nums[a], nums[b] = nums[b], nums[a]
    
    def heapify(self, nums, index):
        left = 2*index + 1
        right = 2*index +2
        size = len(nums)
        
        if size<2:
            return nums
        
        if left <= size-1 and nums[left] > nums[index]:
            self.swap(nums, index, left)
            self.heapify(nums, left)
        if right <= size-1 and nums[right] > nums[index]:
            self.swap(nums, index, right)
            self.heapify(nums, right)
    
    #[4,3.6,2,1] -> [1,3.6,2,4]
    def heapify_down(self, nums):
        for rounds in range(size-1, -1, -1):
            self.swap(nums, 0, rounds)
            result.append(nums.pop())
            self.heapify(nums, 0)
        return result
        
    def heap_sort(self,nums):
        for element in range(size-1, -1, -1):
            self.heapify(nums, element)
        
        ans = self.heapify_down(nums)
        ans = ans[::-1]
        return ans

test = Solution()
test.heap_sort(nums)
# Out:
# [-34, -1, 0, 0, 1, 1, 2, 3.6, 4, 8, 9, 25]

# %% [markdown]
# ## Reference
# 1. [老師提供的程式碼](https://github.com/pecu/DSA/blob/master/06_HeapSort/heapSort.py)
# 2. [Data Structures and Algorithms Bootcamp by Jonathan](https://www.udemy.com/user/jonathanrasmusson/)
