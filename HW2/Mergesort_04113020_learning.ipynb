# %% [markdown]
# # HW2: Merge Sort 學習歷程與Reference
# 陳汶穗｜巨資四B｜04113020

# %% [markdown]
# ## 想法
# - mergesort分成三個行為:分割至最小單位、合併、排序，所以想分成三個function來寫。
# - 對mergesort的理解整理在[Week6: merge-sort筆記](https://github.com/okpersist/108_1_DSA#merge-sort)
#
# 💡以下學習歷程的標題以錯誤和測試為核心，解釋挖掘錯誤或測試的歷程，最終才得出結果。
#
# ## 流程圖
# ![](https://i.imgur.com/CgaK64I.png)
# ![](https://i.imgur.com/CSlpGFb.png)
# ![](https://i.imgur.com/FkTmDYE.png)
# ![](https://i.imgur.com/iIGcQX4.png)
# ![](https://i.imgur.com/N4u8VMm.png)

# %% [markdown]
# ## 測試自己對class的理解
# 一開始看到作業格式並不確定是否可以在main function沒有return是否可以成功印出，所以寫了小class驗證自己的理解是否正確。

# %%
class test:
    def pluss(self,a,b):
        return a+b
    def otherss(self,a,b):
        self.pluss(a,b)
        print(self.pluss(a,b))

A = test()
A.otherss(1,2)
# Out:
# 3

# %% [markdown]
# 第一次寫完整後，遇到的第一個邏輯錯誤(語法錯誤略)
# ## RecursionError: maximum recursion depth exceeded while calling a Python object
# - 錯誤發生時機: <font color=#41D3BD>**遞迴次數超過預設次數時**</font>。python預設是有遞迴次數上限的，所以出現此錯誤。(如果沒有這個防呆機制可能導致記憶體損壞之類)
# - 在下面這段code中，我的mid設錯了，設成取出陣列裡的中間的值，但我需要的是中間值的index，在left, right才分割成較小單位

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = nums[len(nums)//2] #錯誤點
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            
    def merge(self, left, right):
        sorted_result = []
        if left < right:
            sorted_result.append(left)
        else:
            sorted_result.append(right)
            
        if left:
            sorted_result.append(left)
        else :
            sorted_result.append(right)
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-110-16db5e3eccd2> in <module>
#      31
#      32 A = Solution()
# ---> 33 A.merge_sort(nums)
#
# <ipython-input-110-16db5e3eccd2> in merge_sort(self, nums)
#      27
#      28     def merge_sort(self, nums):
# ---> 29         self.divide(nums)
#      30         print(merge)
#      31
#
# <ipython-input-110-16db5e3eccd2> in divide(self, nums)
#       9             right = nums[mid:]
#      10
# ---> 11             left = self.divide(left)
#      12             right = self.divide(right)
#      13             merge = self.merge(left,right)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-110-16db5e3eccd2> in divide(self, nums)
#       9             right = nums[mid:]
#      10
# ---> 11             left = self.divide(left)
#      12             right = self.divide(right)
# ...

# %% [markdown]
# ## TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'
# - 錯誤發生時機: Nonetype無法比大小，debug mode圖如下
# ![](https://i.imgur.com/G6Vbfe7.png)
# - 利用spyder發現邏輯有誤，才導致旁邊value explorer出現`[[1],[1]]`。另外因為放進去的元素是list不是數值，因此換成`extend()`新增進去`sorted_result`，但debug mode排序的結果還是錯的。
# ![](https://i.imgur.com/WLktzwP.png)

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            
    def merge(self, left, right):
        sorted_result = []
        
        if left < right:#錯誤點
            sorted_result.append(left)
        else:
            sorted_result.append(right)
            
        if left:
            sorted_result.append(left)
        else :
            sorted_result.append(right)
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-931689037d82> in <module>
#      32
#      33 A = Solution()
# ---> 34 A.merge_sort(nums)
#
# <ipython-input-111-931689037d82> in merge_sort(self, nums)
#      28
#      29     def merge_sort(self, nums):
# ---> 30         self.divide(nums)
#      31         print(merge)
#      32
#
# <ipython-input-111-931689037d82> in divide(self, nums)
#      11             left = self.divide(left)
#      12             right = self.divide(right)
# ---> 13             merge = self.merge(left,right)
#      14
#      15     def merge(self, left, right):
#
# <ipython-input-111-931689037d82> in merge(self, left, right)
#      16         sorted_result = []
#      17
# ---> 18         if left < right:#錯誤點
#      19             sorted_result.append(left)
#      20         else:
#
# ...

# %% [markdown]
# 👩🏼‍💻移除清單內的值就可以避免元素重複放入，因此在下一個階段嘗試：
# ```python
#        if left[0] < right[0]:#移除清單值，並且每次都比較第一個元素
#             sorted_result.extend(left.pop())
#         else:
#             sorted_result.extend(right.pop())
# ```
# 結果出現
# ## TypeError: 'int' object is not iterable
# - 錯誤發生時機：使用數字進行迭代。迭代的對象不能是數字，例如for loop如果要進行限定次數的迭代要用`range()`。

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            
    def merge(self, left, right):
        sorted_result = []
        
        if left[0] < right[0]:#移除清單值，並且每次都比較第一個元素
            sorted_result.extend(left.pop(0))
        else:
            sorted_result.extend(right.pop(0))
            
        if left:
            sorted_result.extend(left)
        if right:#把else改成if right
            sorted_result.extend(right)
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-08665ba5d38b> in <module>
#      32
#      33 A = Solution()
# ---> 34 A.merge_sort(nums)
#
# <ipython-input-112-08665ba5d38b> in merge_sort(self, nums)
#      28
#      29     def merge_sort(self, nums):
# ---> 30         self.divide(nums)
#      31         print(merge)
#      32
#
# <ipython-input-112-08665ba5d38b> in divide(self, nums)
#       9             right = nums[mid:]
#      10
# ---> 11             left = self.divide(left)
#      12             right = self.divide(right)
#      13             merge = self.merge(left,right)
#
# <ipython-input-112-08665ba5d38b> in divide(self, nums)
#      11             left = self.divide(left)
#      12             right = self.divide(right)
# ---> 13             merge = self.merge(left,right)
#      14
#      15     def merge(self, left, right):
#
# ...

# %% [markdown]
# ![](https://i.imgur.com/VrXGQ5g.png)
# spyder發現`right`的4沒被加進去`sorted_result`，所以把else改成if right，但還是錯

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            
    def merge(self, left, right):
        sorted_result = []
        
        if left[0] < right[0]:
            sorted_result.extend(left.pop(0))
        else:
            sorted_result.extend(right.pop(0))
            
        if left:
            sorted_result.extend(left)
        if right:#把else改成if right
            sorted_result.extend(right)
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-705ee9bd1d2a> in <module>
#      32
#      33 A = Solution()
# ---> 34 A.merge_sort(nums)
#
# <ipython-input-113-705ee9bd1d2a> in merge_sort(self, nums)
#      28
#      29     def merge_sort(self, nums):
# ---> 30         self.divide(nums)
#      31         print(merge)
#      32
#
# <ipython-input-113-705ee9bd1d2a> in divide(self, nums)
#       9             right = nums[mid:]
#      10
# ---> 11             left = self.divide(left)
#      12             right = self.divide(right)
#      13             merge = self.merge(left,right)
#
# <ipython-input-113-705ee9bd1d2a> in divide(self, nums)
#      11             left = self.divide(left)
#      12             right = self.divide(right)
# ---> 13             merge = self.merge(left,right)
#      14
#      15     def merge(self, left, right):
#
# ...

# %% [markdown]
# 👩🏼‍💻卡關很久，跑去參考其他的code，發現`sorted_result`的返回邏輯有問題

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:#新增條件，當left,right都有值才進行比較
            if left[0] < right[0]:
                sorted_result.extend(left.pop(0))
            else:
                sorted_result.extend(right.pop(0))

            if left:
                sorted_result += left #修正sorted_result返回值
            if right:
                sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-c1556bb0f30e> in <module>
#      32
#      33 A = Solution()
# ---> 34 A.merge_sort(nums)
#
# <ipython-input-114-c1556bb0f30e> in merge_sort(self, nums)
#      28
#      29     def merge_sort(self, nums):
# ---> 30         self.divide(nums)
#      31         print(merge)
#      32
#
# <ipython-input-114-c1556bb0f30e> in divide(self, nums)
#       9             right = nums[mid:]
#      10
# ---> 11             left = self.divide(left)
#      12             right = self.divide(right)
#      13             merge = self.merge(left,right)
#
# <ipython-input-114-c1556bb0f30e> in divide(self, nums)
#      11             left = self.divide(left)
#      12             right = self.divide(right)
# ---> 13             merge = self.merge(left,right)
#      14
#      15     def merge(self, left, right):
#
# ...

# %% [markdown]
# ![](https://i.imgur.com/4LWgvTs.png)
# - 新增while限制後發現`extend()`會無法新增值進去`sorted_result`，所以改回`append()`

# %% [markdown]
# 但出現
# ## NameError: name 'merge' is not defined
# - 錯誤出現時機：尚未定義該名詞
# - debug mode發現在下面這段code中, `divide()`的結尾僅有把`merge()`的結果存在`merge`的變數中，但是沒有定義`return`去返回所需的值，因此python將在合併後自動返回`None`。所以合併到最後其實電腦不知道它要幫我們返回甚麼，而在最後一圈時因為`left`&`right`沒有值被返回

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right) #錯誤點
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:
            if left[0] < right[0]:
                sorted_result.append(left.pop(0))
            else:
                sorted_result.append(right.pop(0))

            if left:
                sorted_result += left 
            else:
                sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums) 
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-cf80e37629f0> in <module>
#      32
#      33 A = Solution()
# ---> 34 A.merge_sort(nums)
#
# <ipython-input-115-cf80e37629f0> in merge_sort(self, nums)
#      29     def merge_sort(self, nums):
#      30         self.divide(nums)
# ---> 31         print(merge)
#      32
#      33 A = Solution()
#
# NameError: name 'merge' is not defined

# %% [markdown]
# 👩🏼‍💻加了return結果發現還是一樣

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            return merge
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:
            if left[0] < right[0]:
                sorted_result.append(left.pop(0))
            else:
                sorted_result.append(right.pop(0))

            if left:
                sorted_result += left 
            else:
                sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        self.divide(nums)
        print(merge)
        
A = Solution()
A.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-eb5fc35011ed> in <module>
#      33
#      34 A = Solution()
# ---> 35 A.merge_sort(nums)
#
# <ipython-input-116-eb5fc35011ed> in merge_sort(self, nums)
#      30     def merge_sort(self, nums):
#      31         self.divide(nums)
# ---> 32         print(merge)
#      33
#      34 A = Solution()
#
# NameError: name 'merge' is not defined

# %% [markdown]
# 👩🏼‍💻嘗試更改`merge_sort()`中的結果，新增`ans`變數，可以run但結果是錯的

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]
            
            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
            return merge
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:#新增條件，當left,right都有值才進行比較
            if left[0] < right[0]:
                sorted_result.append(left.pop(0))
            else:
                sorted_result.append(right.pop(0))

            if left:
                sorted_result += left #修正sorted_result返回值
            else:
                sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        ans = self.divide(nums)
        print(ans)
        
A = Solution()
A.merge_sort(nums)
# Out:
# [1, 4, 2, 4, 3.6, 4]

# %% [markdown]
# <font color=#41D3BD>**👩🏼‍💻一百年之後發現`merge()`的縮排邏輯有誤**</font>
#
# 原本的code
# ```python
#     def merge(self, left, right):
#         sorted_result = []
#         while left and right:
#             if left[0] < right[0]:
#                 sorted_result.append(left.pop(0))
#             else:
#                 sorted_result.append(right.pop(0))
#
#             if left:
#                 sorted_result += left
#             else:
#                 sorted_result += right
#         return sorted_result
# ```
# 這個邏輯會導致測試值4被重複加入，其實剩下值的判斷是獨立於left,right有沒有存在的，當檢查完left,right其中一個沒有元素時，把剩下的值一次性的移到`sorted_result`

# %% [markdown]
# ## 最終成果
# 修正return之後就完成了!

# %%
nums = [1, 4, 2, 3.6]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]

            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
        return merge
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:
            if left[0] < right[0]:
                sorted_result.append(left.pop(0))
            else:
                sorted_result.append(right.pop(0))

        if left:
            sorted_result += left
        else:
            sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        ans = self.divide(nums)
        print(ans)
        
A = Solution()
A.merge_sort(nums)
# Out:
# [1, 2, 3.6, 4]

# %% [markdown]
# ## 嘗試其他test

# %%
nums = [3,2,-4,6,4,2,19]
class Solution(object):
    def divide(self, nums):    
        if len(nums)<2:
            return nums
        else:
            mid = len(nums)//2
            left = nums[:mid]
            right = nums[mid:]

            left = self.divide(left)
            right = self.divide(right)
            merge = self.merge(left,right)
        return merge
            
    def merge(self, left, right):
        sorted_result = []
        while left and right:
            if left[0] < right[0]:
                sorted_result.append(left.pop(0))
            else:
                sorted_result.append(right.pop(0))

        if left:
            sorted_result += left
        else:
            sorted_result += right
        return sorted_result
    
    def merge_sort(self, nums):
        ans = self.divide(nums)
        print(ans)
        
A = Solution()
A.merge_sort(nums)
# Out:
# [-4, 2, 2, 3, 4, 6, 19]

# %% [markdown]
# 作業格式
# ```python
# class Solution(object):
#     def merge_sort(self, nums):
#         """
#         :type nums: List[int] ex:[3,2,-4,6,4,2,19],[5,1,1,2,0,0]
#         :rtype: List[int] ex:[-4,2,2,3,4,6,19],[0,0,1,1,2,5]
#         """
# ```

# %% [markdown]
# # Reference
# - [合併排序-維基百科](https://zh.wikipedia.org/wiki/%E5%BD%92%E5%B9%B6%E6%8E%92%E5%BA%8F)
#
# Recursively implementation of Merge Sort
# ```python
# def merge(left, right):
#     result = []
#     while left and right:
#         if left[0] <= right[0]:
#             result.append(left.pop(0))
#         else:
#             result.append(right.pop(0))
#     if left:
#         result += left
#     if right:
#         result += right
#     return result
#
#
# def merge_sort(L):
#     if len(L) <= 1:
#         # When D&C to 1 element, just return it
#         return L
#     mid = len(L) // 2
#     left = L[:mid]
#     right = L[mid:]
#
#     left = merge_sort(left)
#     right = merge_sort(right)
#     # conquer sub-problem recursively
#     return merge(left, right)
#     # return the answer of sub-problem
#
#
# if __name__ == "__main__":
#     test = [1, 4, 2, 3.6, -1, 0, 25, -34, 8, 9, 1, 0]
#     print("original:", test)
#     print("Sorted:", merge_sort(test))
# ```
